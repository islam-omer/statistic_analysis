# %% [markdown]
# ## 1_ Read data using pands

# %%
import pandas as pd
data = pd.read_csv('Cust_Purch_Data.csv')

# %% [markdown]
# ## 2_ show first 18 recorods

# %%
data.head(10)
# Out:
#   prefix    first       last              email  gender  age  \
# 0    Dr.      Ray     Morton    sebvajom@kol.km    Male   38
# 1   Miss  Claudia  Rodriquez      acu@jatsot.ug  Female   51
# 2   Miss    Harry      Meyer          zuz@lo.wf  Female   51
# 3   Miss    Edith    Gilbert  hansohsi@jupec.md  Female   55
# 4    Dr.     Lura     Murphy     webediti@je.st  Female   20
# 5   Mrs.    Andre    McGuire        to@hotvo.ne    Male   50
# 6    Mr.     Cody   Thompson      nebuite@mi.bg  Female   62
# 7    Mr.     Cory     Duncan    rucekefif@zi.mt    Male   36
# 8   Miss  Dorothy    Watkins      cakpez@can.pm  Female   36
# 9    Dr.     Rose       Tate    nafi@kuzrame.ee  Female   53
#
#                                company                 profession  \
# 0                       Medtronic Inc.           Health Therapist
# 1         Ames Department Stores, Inc.           Health Therapist
# 2                            CSX Corp.        Political Scientist
# ...

# %% [markdown]
# ## 3_ get the overview of my data

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 20 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   prefix      30000 non-null  object
#  1   first       30000 non-null  object
#  2   last        30000 non-null  object
#  3   email       30000 non-null  object
#  4   gender      30000 non-null  object
#  5   age         30000 non-null  int64
#  6   company     30000 non-null  object
#  7   profession  30000 non-null  object
#  8   phone       30000 non-null  object
#  9   postal      30000 non-null  object
#  10  province    30000 non-null  object
#  11  cc_no       30000 non-null  int64
#  12  cc_exp      30000 non-null  object
#  13  cc_type     30000 non-null  object
#  14  price(CAD)  30000 non-null  float64
#  15  fav_color   30000 non-null  object
#  16  ip          30000 non-null  object
#  17  weekday     30000 non-null  object
#  18  ampm        30000 non-null  object
# ...

# %% [markdown]
# ## 4_ what are the max, min and mean ages of my customer?

# %%
print ('Max. age of the customer is: ',data['age'].max())
print ('Min. age of the customer is: ',data['age'].min())
print ('Avg. age of the customer is: ',data['age'].mean())
# Out:
# Max. age of the customer is:  65
# Min. age of the customer is:  18
# Avg. age of the customer is:  41.550066666666666

# %% [markdown]
# ## 5_ what are the three most common customer's names?

# %%
data['first'].value_counts().head(4)
# Out:
# first
# Willie     130
# Francis    124
# Eula        86
# Julian      83
# Name: count, dtype: int64

# %% [markdown]
# ## 6_ two customers have the same phone number, can you find those customers?

# %%
data['phone']
# Out:
# phone
# (263) 382-8004    2
# (712) 247-7037    1
# (876) 882-4110    1
# (401) 747-5970    1
# Name: count, dtype: int64

# %%
filtered_data = data[data['phone']== '(263) 382-8004']
filtered_data
# Out:
#    prefix  first   last                email  gender  age            company  \
# 15   Mrs.  Lilly  Tyler      kofadu@itohi.tf  Female   38          CSX Corp.
# 16   Mrs.  Peter   Cain  megkosig@anazeor.gn    Male   27  Campbell Soup Co.
#
#              profession           phone   postal province             cc_no  \
# 15  Structural Engineer  (263) 382-8004  V7K 1E3       ON    30000000000000
# 16   Insurance Adjuster  (263) 382-8004  E8T 2B4       YT  3530000000000000
#
#      cc_exp                    cc_type  price(CAD) fav_color              ip  \
# 15  11/2022  Diners Club Carte Blanche        9.61    Yellow   74.124.37.227
# 16  03/2024                       Solo       13.74     Black  25.207.141.135
#
#      weekday ampm        date
# 15  Saturday   am  03/30/1985
# 16   Tuesday   am  08/05/1950

# %% [markdown]
# ## 7_ how many customers have profession "Structural Engineer"?

# %%
data[data['profession'] == 'Structural Engineer'].count()['first']
# Out:
# 87

# %% [markdown]
# ## 8_ how many male andfemale customers are 'Structural Engineer'?

# %%
data[(data['profession'] == 'Structural Engineer') & (data['gender'] == 'Male')].count()
# Out:
# prefix        43
# first         43
# last          43
# email         43
# gender        43
# age           43
# company       43
# profession    43
# phone         43
# postal        43
# province      43
# cc_no         43
# cc_exp        43
# cc_type       43
# price(CAD)    43
# fav_color     43
# ip            43
# weekday       43
# ampm          43
# date          43
# dtype: int64

# %%
data[(data['profession'] == 'Structural Engineer') & (data['gender'] == 'Female')].count()
# Out:
# prefix        44
# first         44
# last          44
# email         44
# gender        44
# age           44
# company       44
# profession    44
# phone         44
# postal        44
# province      44
# cc_no         44
# cc_exp        44
# cc_type       44
# price(CAD)    44
# fav_color     44
# ip            44
# weekday       44
# ampm          44
# date          44
# dtype: int64

# %% [markdown]
# ## 9_ find out the female structual Engineers from province Alberta (AB)?

# %%
data[(data['profession'] == 'Structural Engineer') & (data['gender'] == 'Female') & (data['province'] == 'AB')]
# Out:
#       prefix first      last              email  gender  age  \
# 8858     Dr.   Roy   Stanley  apiunvo@ehasom.ir  Female   39
# 9058     Mr.  Lora   Kennedy    dennap@rabac.se  Female   51
# 24736   Mrs.  Nell  Richards          dob@me.ki  Female   18
# 29865   Mrs.   Don  McDaniel        naf@zudu.bj  Female   37
#
#                               company           profession           phone  \
# 8858       Cincinnati Financial Corp.  Structural Engineer  (876) 758-2929
# 9058              BJ Services Company  Structural Engineer  (305) 786-6959
# 24736    Telephone & Data Systems Inc  Structural Engineer  (262) 681-5018
# 29865  Anadarko Petroleum Corporation  Structural Engineer  (238) 789-2825
#
#         postal province             cc_no   cc_exp  \
# 8858   N5A 6L2       AB  6300000000000000  02/2022
# 9058   N3R 4B7       AB   201000000000000  06/2019
# 24736  N3Y 3G2       AB   347000000000000  07/2028
# 29865  B4A 8Q9       AB  5610000000000000  12/2022
#
# ...

# %% [markdown]
# ## 10_ what is the max, min and average spending?

# %%
print('Max. spending: ',data['price(CAD)'].max())
print('Min. spending: ',data['price(CAD)'].min())
print('Avg. spending: ',data['price(CAD)'].mean())
# Out:
# Max. spending:  100.0
# Min. spending:  0.0
# Avg. spending:  49.990775

# %% [markdown]
# ## 11_ who did not spend anything? company wants to send a deal to encourge thw customer to buy stuff?

# %%
data[data['price(CAD)'] ==0.0].count()
# Out:
# prefix        2
# first         2
# last          2
# email         2
# gender        2
# age           2
# company       2
# profession    2
# phone         2
# postal        2
# province      2
# cc_no         2
# cc_exp        2
# cc_type       2
# price(CAD)    2
# fav_color     2
# ip            2
# weekday       2
# ampm          2
# date          2
# dtype: int64

# %% [markdown]
# ## 12_ as a loyalty reward, company wants to send thanks coupon to those who spent 100CAD or mor, plese find out the customers?

# %%
data[data['price(CAD)']>=100.0].count()
# Out:
# prefix        3
# first         3
# last          3
# email         3
# gender        3
# age           3
# company       3
# profession    3
# phone         3
# postal        3
# province      3
# cc_no         3
# cc_exp        3
# cc_type       3
# price(CAD)    3
# fav_color     3
# ip            3
# weekday       3
# ampm          3
# date          3
# dtype: int64

# %% [markdown]
# ## 13_ how many emails are associated with this credit card number '5020000000000230'?

# %%
data[data['cc_no']==5020000000000230].count()
# Out:
# prefix        2
# first         2
# last          2
# email         2
# gender        2
# age           2
# company       2
# profession    2
# phone         2
# postal        2
# province      2
# cc_no         2
# cc_exp        2
# cc_type       2
# price(CAD)    2
# fav_color     2
# ip            2
# weekday       2
# ampm          2
# date          2
# dtype: int64

# %%
data[data['cc_no']==5020000000000230]['email']
# Out:
# 0    sebvajom@kol.km
# 1      acu@jatsot.ug
# Name: email, dtype: object

# %% [markdown]
# ## 14_ we need to send new cards to the customers well before the expire, how many cards are expiring in 2019?

# %%
data['cc_exp'].head(4)
# Out:
# 0    05/2018
# 1    07/2028
# 2    02/2023
# 3    02/2028
# Name: cc_exp, dtype: object

# %%
data.dtypes
# Out:
# prefix         object
# first          object
# last           object
# email          object
# gender         object
# age             int64
# company        object
# profession     object
# phone          object
# postal         object
# province       object
# cc_no           int64
# cc_exp         object
# cc_type        object
# price(CAD)    float64
# fav_color      object
# ip             object
# weekday        object
# ampm           object
# date           object
# dtype: object

# %%
data['cc_exp'].head(3)
# Out:
# 0    05/2018
# 1    07/2028
# 2    02/2023
# Name: cc_exp, dtype: object

# %%
sum(data['cc_exp'].apply(lambda x: x[3:]) == "2019")
# Out:
# 2684

# %%
data[data['cc_exp'].apply(lambda x: x[5:]) == '19'].count()
# Out:
# prefix        2684
# first         2684
# last          2684
# email         2684
# gender        2684
# age           2684
# company       2684
# profession    2684
# phone         2684
# postal        2684
# province      2684
# cc_no         2684
# cc_exp        2684
# cc_type       2684
# price(CAD)    2684
# fav_color     2684
# ip            2684
# weekday       2684
# ampm          2684
# date          2684
# dtype: int64

# %% [markdown]
# ## 15_ how many people use visa as their Credit Provider?

# %%
sum(data['cc_type']== 'Visa')
# Out:
# 1721

# %%
sum(data['cc_type']== 'Discover Card')
# Out:
# 1739

# %% [markdown]
# ## 16_ can you find the customer who spent 100 CAD using visa?

# %%
data[(data['cc_type']=='Visa') & (data['price(CAD)'] ==100.0)]
# Out:
#    prefix    first   last       email  gender  age              company  \
# 76   Mrs.  Gregory  Brown  hav@jek.gs  Female   31  E*Trade Group, Inc.
#
#    profession           phone   postal province             cc_no   cc_exp  \
# 76   Novelist  (625) 537-8923  X3S 4Q2       PE  6010000000000000  04/2018
#
#    cc_type  price(CAD) fav_color             ip weekday ampm        date
# 76    Visa       100.0     Green  212.100.18.95  Monday   am  10/23/2063

# %% [markdown]
# ## 17_ what are two most common professions?

# %%
data['profession'].value_counts().head(4)
# Out:
# profession
# Preschool Teacher         112
# Distribution Manager      107
# Scientific Programmer     106
# Hospital Administrator    102
# Name: count, dtype: int64

# %% [markdown]
# ## 18_ can you tell the top 5 most popular email providers? (e.g gmail.com, yahoo.com, etc..)

# %%
data.head(5)
# Out:
#   prefix    first       last              email  gender  age  \
# 0    Dr.      Ray     Morton    sebvajom@kol.km    Male   38
# 1   Miss  Claudia  Rodriquez      acu@jatsot.ug  Female   51
# 2   Miss    Harry      Meyer          zuz@lo.wf  Female   51
# 3   Miss    Edith    Gilbert  hansohsi@jupec.md  Female   55
# 4    Dr.     Lura     Murphy     webediti@je.st  Female   20
#
#                         company              profession           phone  \
# 0                Medtronic Inc.        Health Therapist  (987) 619-2695
# 1  Ames Department Stores, Inc.        Health Therapist  (356) 736-7352
# 2                     CSX Corp.     Political Scientist  (539) 246-1806
# 3        Murphy Oil Corporation  Transportation Manager  (984) 962-7494
# 4                  PETsMART Inc            Statistician  (902) 568-9748
#
#     postal province             cc_no   cc_exp                    cc_type  \
# 0  B6V 3W3       MB  5020000000000230  05/2018                       Solo
# ...

# %%
data['email'].apply(lambda x: x.split('@')[1]).value_counts().head(5)
# Out:
# email
# gmail.com      1687
# me.com         1676
# outlook.com    1664
# live.com       1660
# hotmail.com    1659
# Name: count, dtype: int64

# %% [markdown]
# ## 19_ is there any customers who is using email with "am.edu"?

# %%
data[data['email'].apply(lambda x: x.split('@')[1])=='gmail.com']
# Out:
#      prefix    first      last                email  gender  age  \
# 198     Mr.    Jerry      Moss  jufkettug@gmail.com    Male   43
# 201     Mr.    Peter    Gibson   oniweput@gmail.com    Male   27
# 204    Miss    Gavin  Gonzales   gebasise@gmail.com    Male   62
# 205     Dr.    Peter     Reese      sefed@gmail.com    Male   55
# 209     Dr.     Rose      Dean     robleg@gmail.com    Male   35
# ...     ...      ...       ...                  ...     ...  ...
# 5176   Mrs.  Chester    Norton    dehozic@gmail.com    Male   37
# 5183   Mrs.     Cole    Medina    vuputum@gmail.com  Female   23
# 5184    Mr.   Lettie   Pittman   pofizwew@gmail.com    Male   55
# 5192   Miss     Lola      Webb   ledhinep@gmail.com    Male   32
# 5196    Mr.   Jeremy    Oliver      uhepu@gmail.com  Female   44
#
#                                                 company  \
# 198                                     Earthlink, Inc.
# 201                                         Praxair Inc
# ...

# %% [markdown]
# ## 20_ which day of the week the stor gets more customers?

# %%
data['weekday'].value_counts().head()
# Out:
# weekday
# Saturday     4376
# Wednesday    4365
# Thursday     4327
# Friday       4316
# Monday       4216
# Name: count, dtype: int64
